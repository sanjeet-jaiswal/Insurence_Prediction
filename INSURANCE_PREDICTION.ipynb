# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Sanjeet Jaiswal\Downloads\Machine Learning\Insurance Prediction\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(20)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(6,8))
sns.distplot(df['age'])
plt.title("Age Distribution")
plt.show()
# Out:
# C:\Users\Sanjeet Jaiswal\AppData\Local\Temp\ipykernel_12152\3020976630.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])

# %%
plt.figure(figsize=(6,8))
sns.countplot(x="sex",data=df)
plt.title("Sex Distribution")
plt.show()

# %%
sns.set()
plt.figure(figsize=(6,8))
sns.distplot(df['bmi'])
plt.title("Age Distribution")
plt.show()
# Out:
# C:\Users\Sanjeet Jaiswal\AppData\Local\Temp\ipykernel_12152\1923663792.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bmi'])

# %%
df["sex"].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
df["children"].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,8))
sns.countplot(x="children",data=df)
plt.title("Sex Distribution")
plt.show()

# %%
plt.figure(figsize=(6,8))
sns.countplot(x="region",data=df)
plt.title("Sex Distribution")
plt.show()

# %%
plt.figure(figsize=(6,8))
sns.countplot(x="smoker",data=df)
plt.title("Sex Distribution")
plt.show()

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['charges'])
plt.title("Age Distribution")
plt.show()
# Out:
# C:\Users\Sanjeet Jaiswal\AppData\Local\Temp\ipykernel_12152\3835183460.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['charges'])

# %%
# encoding sex column
df.replace({"sex":{"male":0,"female":1}},inplace=True)

# encoding smoker column
df.replace({"smoker":{"yes":0,"no":1}},inplace=True)

# encoding region column
df.replace({"region":{"southeast":0,"southwest":1,"northeast":2,"northwest":4}},inplace=True)
# Out:
# C:\Users\Sanjeet Jaiswal\AppData\Local\Temp\ipykernel_12152\4109914685.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"sex":{"male":0,"female":1}},inplace=True)
# C:\Users\Sanjeet Jaiswal\AppData\Local\Temp\ipykernel_12152\4109914685.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"smoker":{"yes":0,"no":1}},inplace=True)
# ...

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       0       1  16884.92400
# 1      18    0  33.770         1       1       0   1725.55230
# 2      28    0  33.000         3       1       0   4449.46200
# 3      33    0  22.705         0       1       4  21984.47061
# 4      32    0  28.880         0       1       4   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       1       4  10600.54830
# 1334   18    1  31.920         0       1       2   2205.98080
# 1335   18    1  36.850         0       1       0   1629.83350
# 1336   21    1  25.800         0       1       1   2007.94500
# 1337   61    1  29.070         0       0       4  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
#  ### Splitting the Features and Target

# %%
x=df.drop(columns="charges",axis=1)  # target column
y=df["charges"] # feature column

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       4
# 4      32    0  28.880         0       1       4
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       4
# 1334   18    1  31.920         0       1       2
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       4
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# splitting the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %% [markdown]
# ### Model Selection

# %%
# loading the Linear Regression model

regressor=LinearRegression()

# %% [markdown]
# ### Model Training

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Evaluaton

# %%
# prediction on training data
training_data_prediction=regressor.predict(x_train)

# %%
# R squared value test
r2_train=metrics.r2_score(y_train,training_data_prediction)
print("R squared value : ",r2_train)
# Out:
# R squared value :  0.7514085919979442

# %%
# prediction on test data
test_data_prediction=regressor.predict(x_test)

# %%
# R square value test
r2_test=metrics.r2_score(y_test,test_data_prediction)
print("R squared value : ",r2_test)
# Out:
# R squared value :  0.7443018651235679

# %% [markdown]
# ### Prediction on input data

# %%
input_data = (31,1,25.74,0,1,0)

# changing input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = regressor.predict(input_data_reshaped)
print(prediction)

print('The insurance cost is USD ', prediction[0])
# Out:
# [3844.97439715]
# The insurance cost is USD  3844.974397150272
# C:\Users\Sanjeet Jaiswal\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       0       1  16884.92400
# 1      18    0  33.770         1       1       0   1725.55230
# 2      28    0  33.000         3       1       0   4449.46200
# 3      33    0  22.705         0       1       4  21984.47061
# 4      32    0  28.880         0       1       4   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       1       4  10600.54830
# 1334   18    1  31.920         0       1       2   2205.98080
# 1335   18    1  36.850         0       1       0   1629.83350
# 1336   21    1  25.800         0       1       1   2007.94500
# 1337   61    1  29.070         0       0       4  29141.36030
#
# [1338 rows x 7 columns]

# %%
import joblib
joblib.dump(regressor,"insurence.pkl")
# Out:
# ['insurence.pkl']

# %%
np.__version__
# Out:
# '1.26.4'

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.2'

# %%
import sklearn
sklearn.__version__
# Out:
# '1.8.0'

# %%
joblib.__version__
# Out:
# '1.4.2'

# %%
import scikit-learn
scikit-learn.__version__
# Out:
#   Cell In[48], line 1
#     import scikit-learn
#                  ^
# SyntaxError: invalid syntax
